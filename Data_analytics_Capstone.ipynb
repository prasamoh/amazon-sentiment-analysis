# %%
#Install and import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import json

from tqdm import tqdm
from textblob import TextBlob
from wordcloud import WordCloud

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# File path
file_path = "/content/amazon_raw_flat.csv"

# Load CSV into DataFrame
df = pd.read_csv(file_path)

# Basic checks
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (13070, 168)
# /tmp/ipykernel_7599/4116054303.py:5: DtypeWarning: Columns (29,42,43,46,62,63,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#     type                   id  \
# 0  tweet  2008327517346685380
# 1  tweet  2008327414825243105
# 2  tweet  2008327358852239685
# 3  tweet  2008327351856156805
# 4  tweet  2008327284151681107
#
#                                                  url  \
# 0  https://x.com/PriceErrors_/status/200832751734...
# 1  https://x.com/dipperid/status/2008327414825243105
# 2  https://x.com/lberrelez32/status/2008327358852...
# 3  https://x.com/PCPartsDrop/status/2008327351856...
# 4  https://x.com/c__honey/status/2008327284151681107
#
#                                           twitterUrl  \
# 0  https://twitter.com/PriceErrors_/status/200832...
# 1  https://twitter.com/dipperid/status/2008327414...
# 2  https://twitter.com/lberrelez32/status/2008327...
# 3  https://twitter.com/PCPartsDrop/status/2008327...
# 4  https://twitter.com/c__honey/status/2008327284...
#
#                                                 text  \
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...
# 1  Destiny is on a show called Party Lines' on Am...
# 2  Thank you @SenateTim for the generous donation...
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...
# 4  Finds something on TikTok.. goes straight to A...
#
#                                             fullText              source  \
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...     Twitter Web App
# 1  Destiny is on a show called Party Lines' on Am...     Twitter Web App
# 2  Thank you @SenateTim for the generous donation...  Twitter for iPhone
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...     Twitter Web App
# 4  Finds something on TikTok.. goes straight to A...  Twitter for iPhone
#
#    retweetCount  replyCount  likeCount  ...  quote.place.full_name  \
# 0             0           0          0  ...                    NaN
# 1            14          26        500  ...                    NaN
# 2             1           0          2  ...                    NaN
# 3             0           0          0  ...                    NaN
# 4             0           0          0  ...                    NaN
#
#    quote.place.id quote.place.name quote.place.place_type  quote.place.url  \
# 0             NaN              NaN                    NaN              NaN
# 1             NaN              NaN                    NaN              NaN
# 2             NaN              NaN                    NaN              NaN
# 3             NaN              NaN                    NaN              NaN
# 4             NaN              NaN                    NaN              NaN
#
#    quote.author.withheldInCountries  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    quote.author.affiliatesHighlightedLabel.label.longDescription.entities  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   quote.author.affiliatesHighlightedLabel.label.longDescription.text  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   quote.url  quote.twitterUrl
# 0       NaN               NaN
# 1       NaN               NaN
# 2       NaN               NaN
# 3       NaN               NaN
# 4       NaN               NaN
#
# [5 rows x 168 columns]

# %%
print(df.columns.tolist())
# Out:
# ['type', 'id', 'url', 'twitterUrl', 'text', 'fullText', 'source', 'retweetCount', 'replyCount', 'likeCount', 'quoteCount', 'viewCount', 'createdAt', 'lang', 'bookmarkCount', 'isReply', 'conversationId', 'possiblySensitive', 'isPinned', 'isRetweet', 'isQuote', 'media', 'isConversationControlled', 'author.type', 'author.userName', 'author.url', 'author.twitterUrl', 'author.id', 'author.name', 'author.isBlueVerified', 'author.profilePicture', 'author.coverPicture', 'author.description', 'author.followers', 'author.following', 'author.status', 'author.canDm', 'author.canMediaTag', 'author.createdAt', 'author.entities.url.urls', 'author.fastFollowersCount', 'author.favouritesCount', 'author.hasCustomTimelines', 'author.isTranslator', 'author.mediaCount', 'author.statusesCount', 'author.possiblySensitive', 'author.pinnedTweetIds', 'extendedEntities.media', 'entities.hashtags', 'entities.media', 'entities.symbols', 'entities.timestamps', 'entities.urls', 'entities.user_mentions', 'author.location', 'author.entities.description.urls', 'author.professional.category', 'author.professional.professional_type', 'author.professional.rest_id', 'author.affiliatesHighlightedLabel.label.badge.url', 'author.affiliatesHighlightedLabel.label.description', 'author.affiliatesHighlightedLabel.label.longDescription.entities', 'author.affiliatesHighlightedLabel.label.longDescription.text', 'author.affiliatesHighlightedLabel.label.userLabelType', 'card.legacy.binding_values', 'card.legacy.card_platform.platform.audience.name', 'card.legacy.card_platform.platform.device.name', 'card.legacy.card_platform.platform.device.version', 'card.legacy.name', 'card.legacy.url', 'card.legacy.user_refs_results', 'card.rest_id', 'quoteId', 'quote.type', 'quote.id', 'quote.text', 'quote.source', 'quote.retweetCount', 'quote.replyCount', 'quote.likeCount', 'quote.quoteCount', 'quote.viewCount', 'quote.createdAt', 'quote.lang', 'quote.bookmarkCount', 'quote.possiblySensitive', 'quote.author.type', 'quote.author.userName', 'quote.author.url', 'quote.author.twitterUrl', 'quote.author.id', 'quote.author.name', 'quote.author.isBlueVerified', 'quote.author.profilePicture', 'quote.author.coverPicture', 'quote.author.description', 'quote.author.location', 'quote.author.followers', 'quote.author.following', 'quote.author.status', 'quote.author.canDm', 'quote.author.canMediaTag', 'quote.author.createdAt', 'quote.author.fastFollowersCount', 'quote.author.favouritesCount', 'quote.author.hasCustomTimelines', 'quote.author.isTranslator', 'quote.author.mediaCount', 'quote.author.statusesCount', 'quote.author.possiblySensitive', 'quote.author.professional.category', 'quote.author.professional.professional_type', 'quote.author.professional.rest_id', 'quote.extendedEntities.media', 'quote.entities.hashtags', 'quote.entities.media', 'quote.entities.symbols', 'quote.entities.timestamps', 'quote.entities.urls', 'quote.entities.user_mentions', 'quote.isPinned', 'quote.author.entities.url.urls', 'quote.author.pinnedTweetIds', 'author.affiliatesHighlightedLabel.label.url.url', 'author.affiliatesHighlightedLabel.label.url.urlType', 'author.affiliatesHighlightedLabel.label.userLabelDisplayType', 'quote.author.entities.description.urls', 'quote.author.affiliatesHighlightedLabel.label.badge.url', 'quote.author.affiliatesHighlightedLabel.label.description', 'quote.author.affiliatesHighlightedLabel.label.url.url', 'quote.author.affiliatesHighlightedLabel.label.url.urlType', 'quote.author.affiliatesHighlightedLabel.label.userLabelDisplayType', 'quote.author.affiliatesHighlightedLabel.label.userLabelType', 'place.bounding_box.coordinates', 'place.bounding_box.type', 'place.country', 'place.country_code', 'place.full_name', 'place.id', 'place.name', 'place.place_type', 'place.url', 'quote.card.legacy.binding_values', 'quote.card.legacy.card_platform.platform.audience.name', 'quote.card.legacy.card_platform.platform.device.name', 'quote.card.legacy.card_platform.platform.device.version', 'quote.card.leg ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13070 entries, 0 to 13069
# Columns: 168 entries, type to quote.twitterUrl
# dtypes: bool(6), float64(30), int64(7), object(125)
# memory usage: 16.2+ MB

# %%
#selecting only the needed and meaningful columns

# Select only relevant columns based on your dataset
selected_columns = [
    'id',
    'url',
    'fullText',
    'text',
    'createdAt',
    'lang',
    'retweetCount',
    'replyCount',
    'likeCount',
    'quoteCount',
    'viewCount',
    'author.userName',
    'author.followers',
    'entities.hashtags'
]

# Keep only columns that actually exist
existing_columns = [col for col in selected_columns if col in df.columns]

df_selected = df[existing_columns].copy()

print("Selected shape:", df_selected.shape)
df_selected.head()
# Out:
# Selected shape: (13070, 14)
#                     id                                                url  \
# 0  2008327517346685380  https://x.com/PriceErrors_/status/200832751734...
# 1  2008327414825243105  https://x.com/dipperid/status/2008327414825243105
# 2  2008327358852239685  https://x.com/lberrelez32/status/2008327358852...
# 3  2008327351856156805  https://x.com/PCPartsDrop/status/2008327351856...
# 4  2008327284151681107  https://x.com/c__honey/status/2008327284151681107
#
#                                             fullText  \
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...
# 1  Destiny is on a show called Party Lines' on Am...
# 2  Thank you @SenateTim for the generous donation...
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...
# 4  Finds something on TikTok.. goes straight to A...
#
#                                                 text  \
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...
# 1  Destiny is on a show called Party Lines' on Am...
# 2  Thank you @SenateTim for the generous donation...
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...
# 4  Finds something on TikTok.. goes straight to A...
#
#                         createdAt lang  retweetCount  replyCount  likeCount  \
# 0  Mon Jan 05 23:59:27 +0000 2026   en             0           0          0
# 1  Mon Jan 05 23:59:03 +0000 2026   en            14          26        500
# 2  Mon Jan 05 23:58:49 +0000 2026   en             1           0          2
# 3  Mon Jan 05 23:58:48 +0000 2026   en             0           0          0
# 4  Mon Jan 05 23:58:32 +0000 2026   en             0           0          0
#
#    quoteCount  viewCount author.userName  author.followers  \
# 0           0      107.0    PriceErrors_            7964.0
# 1           5    46767.0        dipperid             912.0
# 2           0       53.0     lberrelez32           10803.0
# 3           0       95.0     PCPartsDrop            1458.0
# 4           0       22.0        c__honey             627.0
#
#                          entities.hashtags
# 0                                       []
# 1                                       []
# 2                                       []
# 3  [{'indices': [263, 266], 'text': 'ad'}]
# 4                                       []

# %%
#Create main text column

# Create unified text column
df_selected['tweet_text'] = df_selected['fullText'].fillna(df_selected['text'])

# Convert to string (important for NLP)
df_selected['tweet_text'] = df_selected['tweet_text'].astype(str)

# Check
df_selected[['tweet_text']].head()
# Out:
#                                           tweet_text
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...
# 1  Destiny is on a show called Party Lines' on Am...
# 2  Thank you @SenateTim for the generous donation...
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...
# 4  Finds something on TikTok.. goes straight to A...

# %%
#Quick sanity checks

# Check missing text
print("Missing text:", df_selected['tweet_text'].isna().sum())

# Check duplicates
print("Duplicate tweets:", df_selected.duplicated(subset=['tweet_text']).sum())

# Language distribution
print(df_selected['lang'].value_counts().head())
# Out:
# Missing text: 0
# Duplicate tweets: 81
# lang
# en    13070
# Name: count, dtype: int64

# %%
#filter only English tweets

df_selected = df_selected[df_selected['lang'] == 'en']

print("After English filter:", df_selected.shape)
# Out:
# After English filter: (13070, 15)

# %%
# Remove duplicates and finalize base dataset

# Remove duplicate tweets
df_clean = df_selected.drop_duplicates(subset=['tweet_text']).copy()

print("Shape after removing duplicates:", df_clean.shape)
# Out:
# Shape after removing duplicates: (12989, 15)

# %%
# Clean tweet text for NLP

import re
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "", text)      # remove URLs
    text = re.sub(r"@\w+", "", text)               # remove mentions
    text = re.sub(r"#", "", text)                  # remove hashtag symbol
    text = re.sub(r"[^a-z\s]", "", text)           # keep only letters
    text = re.sub(r"\s+", " ", text).strip()       # remove extra spaces

    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]

    return " ".join(tokens)

df_clean['clean_text'] = df_clean['tweet_text'].apply(clean_text)

df_clean[['tweet_text', 'clean_text']].head()
# Out:
#                                           tweet_text  \
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...
# 1  Destiny is on a show called Party Lines' on Am...
# 2  Thank you @SenateTim for the generous donation...
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...
# 4  Finds something on TikTok.. goes straight to A...
#
#                                           clean_text
# 0  road comforts car seat covers xx reg xx clip c...
# 1  destiny show called party lines amazon prime v...
# 2  thank generous donation much needed pencils un...
# 3  amazon open box acceptable condition asus rog ...
# 4  finds something tiktok goes straight amazon ge...

# %%
# Create time-based features

df_clean['createdAt'] = pd.to_datetime(df_clean['createdAt'], errors='coerce')

df_clean['date'] = df_clean['createdAt'].dt.date
df_clean['hour'] = df_clean['createdAt'].dt.hour
df_clean['day_of_week'] = df_clean['createdAt'].dt.day_name()

df_clean.head()
# Out:
# /tmp/ipykernel_7599/2145281201.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean['createdAt'] = pd.to_datetime(df_clean['createdAt'], errors='coerce')
#                     id                                                url  \
# 0  2008327517346685380  https://x.com/PriceErrors_/status/200832751734...
# 1  2008327414825243105  https://x.com/dipperid/status/2008327414825243105
# 2  2008327358852239685  https://x.com/lberrelez32/status/2008327358852...
# 3  2008327351856156805  https://x.com/PCPartsDrop/status/2008327351856...
# 4  2008327284151681107  https://x.com/c__honey/status/2008327284151681107
#
#                                             fullText  \
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...
# 1  Destiny is on a show called Party Lines' on Am...
# 2  Thank you @SenateTim for the generous donation...
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...
# 4  Finds something on TikTok.. goes straight to A...
#
#                                                 text  \
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...
# 1  Destiny is on a show called Party Lines' on Am...
# 2  Thank you @SenateTim for the generous donation...
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...
# 4  Finds something on TikTok.. goes straight to A...
#
#                   createdAt lang  retweetCount  replyCount  likeCount  \
# 0 2026-01-05 23:59:27+00:00   en             0           0          0
# 1 2026-01-05 23:59:03+00:00   en            14          26        500
# 2 2026-01-05 23:58:49+00:00   en             1           0          2
# 3 2026-01-05 23:58:48+00:00   en             0           0          0
# 4 2026-01-05 23:58:32+00:00   en             0           0          0
#
#    quoteCount  viewCount author.userName  author.followers  \
# 0           0      107.0    PriceErrors_            7964.0
# 1           5    46767.0        dipperid             912.0
# 2           0       53.0     lberrelez32           10803.0
# 3           0       95.0     PCPartsDrop            1458.0
# 4           0       22.0        c__honey             627.0
#
#                          entities.hashtags  \
# 0                                       []
# 1                                       []
# 2                                       []
# 3  [{'indices': [263, 266], 'text': 'ad'}]
# 4                                       []
#
#                                           tweet_text  \
# 0  Road Comforts Car Seat Covers\n\nNow $28.xx\nR...
# 1  Destiny is on a show called Party Lines' on Am...
# 2  Thank you @SenateTim for the generous donation...
# 3  Amazon Open Box [$202.65, $97.34 (32%) off, Ac...
# 4  Finds something on TikTok.. goes straight to A...
#
#                                           clean_text        date  hour  \
# 0  road comforts car seat covers xx reg xx clip c...  2026-01-05    23
# 1  destiny show called party lines amazon prime v...  2026-01-05    23
# 2  thank generous donation much needed pencils un...  2026-01-05    23
# 3  amazon open box acceptable condition asus rog ...  2026-01-05    23
# 4  finds something tiktok goes straight amazon ge...  2026-01-05    23
#
#   day_of_week
# 0      Monday
# 1      Monday
# 2      Monday
# 3      Monday
# 4      Monday

# %%
# from textblob import TextBlob

def get_sentiment_score(text):
    return TextBlob(text).sentiment.polarity

def get_sentiment_label(score):
    if score > 0.05:
        return "Positive"
    elif score < -0.05:
        return "Negative"
    else:
        return "Neutral"

df_clean['sentiment_score'] = df_clean['clean_text'].apply(get_sentiment_score)
df_clean['sentiment_label'] = df_clean['sentiment_score'].apply(get_sentiment_label)

df_clean[['clean_text', 'sentiment_score', 'sentiment_label']].head()
# Out:
#                                           clean_text  sentiment_score  \
# 0  road comforts car seat covers xx reg xx clip c...              0.0
# 1  destiny show called party lines amazon prime v...              0.0
# 2  thank generous donation much needed pencils un...              0.1
# 3  amazon open box acceptable condition asus rog ...              0.0
# 4  finds something tiktok goes straight amazon ge...              0.5
#
#   sentiment_label
# 0         Neutral
# 1         Neutral
# 2        Positive
# 3         Neutral
# 4        Positive

# %%
print(df_clean['sentiment_label'].value_counts())
# Out:
# sentiment_label
# Positive    6102
# Neutral     5189
# Negative    1698
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
sns.countplot(data=df_clean, x='sentiment_label')
plt.title("Figure 1. Distribution of Sentiment in Supply Chain Tweets")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
# Engagement vs sentiment

engagement_cols = ['retweetCount', 'replyCount', 'likeCount', 'quoteCount', 'viewCount']

for col in engagement_cols:
    df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')

engagement_by_sentiment = df_clean.groupby('sentiment_label')[engagement_cols].mean()

engagement_by_sentiment
# Out:
#                  retweetCount  replyCount  likeCount  quoteCount    viewCount
# sentiment_label
# Negative             6.267373    1.898704  30.378681    0.478210  3643.719621
# Neutral              6.105415    1.732897  38.640971    0.441318  3972.631251
# Positive             6.331695    1.703540  32.208620    0.395444  2812.678855

# %%
engagement_by_sentiment.plot(kind='bar', figsize=(10,6))
plt.title("Figure 2. Average Engagement by Sentiment")
plt.ylabel("Average Count")
plt.xticks(rotation=0)
plt.show()

# %%
# Define operational themes

theme_keywords = {
    "Delivery Delay": [
        "delay", "late", "delayed", "waiting", "took long",
        "not delivered", "delivery time", "arrive", "arrival"
    ],
    "Fulfillment Issue": [
        "missing", "wrong item", "damaged", "broken",
        "cancelled", "canceled", "refund", "return"
    ],
    "Last Mile Issue": [
        "driver", "courier", "delivery person",
        "doorstep", "address issue"
    ],
    "Customer Service": [
        "support", "customer service", "help",
        "no response", "call", "chat", "helpline"
    ],
    "Tracking Issue": [
        "tracking", "no update", "status",
        "not updated", "location", "where is my order"
    ]
}

# %%
# Assign themes to each tweet

def assign_single_theme(text):
    for theme, keywords in theme_keywords.items():
        for keyword in keywords:
            if keyword in text:
                return theme
    return "Other"

df_clean['theme'] = df_clean['clean_text'].apply(assign_single_theme)

# %%
theme_counts = df_clean['theme'].value_counts()
print(theme_counts)
# Out:
# theme
# Other                11270
# Customer Service       740
# Delivery Delay         474
# Fulfillment Issue      328
# Last Mile Issue        124
# Tracking Issue          53
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df_clean, y='theme', order=theme_counts.index)
plt.title("Distribution of Operational Themes")
plt.xlabel("Count")
plt.ylabel("Theme")
plt.show()

# %%
df_clean[df_clean['theme'] == "Other"]['tweet_text'].sample(20, random_state=42)
# Out:
# 11534    New Amazon Coupons for October 19 – Fresh Deal...
# 2914     Mother throws Amazon Alexa device out of house...
# 4555     https://t.co/R6QuPaX3OA\nAmazon deals with ama...
# 5845     Survival in the Amazon: A woman recounts a bru...
# 7411     PS5 Slim is only $379.99 at Woot from Amazon: ...
# 11560    Apple Watch Series 10 [GPS + Cellular, 42mm] -...
# 8280     Know what? Never mind. EDC your Turkshit gun. ...
# 10708    In the Old West, sometimes blood was the only ...
# 11531    Amazon Essentials Women’s Long-Sleeve Crewneck...
# 747      It’s cold outside, which makes it a great time...
# 11062    Excited to see Websea launch TradFi Perpetual ...
# 9093     How to receive Amazon payments in Algeria http...
# 3593     Damn I guess we know where the FCC stands on t...
# 7266     Amazon Ads:\n\nSpend: $41.54\nSales: $1,433.49...
# 13063    Amazon [$1,069.99]: ASUS TUF Gaming GeForce RT...
# 2450     Consider reading "Tomorrow and Tomorrow and To...
# 7237     Summer sale is live now\nFlat 20% Off on Our W...
# 7163     A growing number of technology executives are ...
# 3893     [Tech Arena] Nutanix, AWS and Datamellon Host ...
# 7542     Fatebreaker: Book One of the God Game https://...
# Name: tweet_text, dtype: object

# %%
df_clean[df_clean['theme'] == "Other"][['tweet_text', 'clean_text']].sample(20, random_state=42)
# Out:
#                                               tweet_text  \
# 11534  New Amazon Coupons for October 19 – Fresh Deal...
# 2914   Mother throws Amazon Alexa device out of house...
# 4555   https://t.co/R6QuPaX3OA\nAmazon deals with ama...
# 5845   Survival in the Amazon: A woman recounts a bru...
# 7411   PS5 Slim is only $379.99 at Woot from Amazon: ...
# 11560  Apple Watch Series 10 [GPS + Cellular, 42mm] -...
# 8280   Know what? Never mind. EDC your Turkshit gun. ...
# 10708  In the Old West, sometimes blood was the only ...
# 11531  Amazon Essentials Women’s Long-Sleeve Crewneck...
# 747    It’s cold outside, which makes it a great time...
# 11062  Excited to see Websea launch TradFi Perpetual ...
# 9093   How to receive Amazon payments in Algeria http...
# 3593   Damn I guess we know where the FCC stands on t...
# 7266   Amazon Ads:\n\nSpend: $41.54\nSales: $1,433.49...
# 13063  Amazon [$1,069.99]: ASUS TUF Gaming GeForce RT...
# 2450   Consider reading "Tomorrow and Tomorrow and To...
# 7237   Summer sale is live now\nFlat 20% Off on Our W...
# 7163   A growing number of technology executives are ...
# 3893   [Tech Arena] Nutanix, AWS and Datamellon Host ...
# 7542   Fatebreaker: Book One of the God Game https://...
#
#                                               clean_text
# 11534  new amazon coupons october fresh deals need cl...
# 2914   mother throws amazon alexa device house asked ...
# 4555                         amazon deals amazing offers
# 5845   survival amazon woman recounts brutal attack l...
# 7411   ps slim woot amazon ad free shipping prime goe...
# 11560  apple watch series gps cellular mm silver alum...
# 8280   know never mind edc turkshit gun fuck tourniqu...
# 10708  old west sometimes blood thing could set man f...
# 11531  amazon essentials womens longsleeve crewneck s...
# 747    cold outside makes great time get lost new boo...
# 11062  excited see websea launch tradfi perpetual fut...
# 9093                     receive amazon payments algeria
# 3593   damn guess know fcc stands amazon objection sp...
# 7266   amazon ads spend sales acos days st month bad ...
# 13063           amazon asus tuf gaming geforce rtx ti ad
# 2450   consider reading tomorrow tomorrow tomorrow en...
# 7237   summer sale live flat website shop also availa...
# 7163   growing number technology executives pointing ...
# 3893   tech arena nutanix aws datamellon host executi...
# 7542            fatebreaker book one god game amazon via

# %%
from collections import Counter

other_text = " ".join(df_clean[df_clean['theme'] == "Other"]['clean_text'])
word_counts = Counter(other_text.split())

common_words = pd.DataFrame(word_counts.most_common(30), columns=['word', 'count'])
common_words
# Out:
#          word  count
# 0      amazon  10213
# 1          ad   1712
# 2         amp   1046
# 3        book    864
# 4       price    815
# 5       music    810
# 6         via    751
# 7        deal    706
# 8         new    677
# 9         one    656
# 10         ai    623
# 11       free    616
# 12        get    599
# 13  available    592
# 14      check    584
# 15      deals    566
# 16       like    557
# 17      prime    553
# 18     spring    523
# 19       sale    506
# 20        buy    497
# 21        big    482
# 22       time    401
# 23       link    385
# 24      today    380
# 25       code    366
# 26         us    365
# 27          k    348
# 28      apple    347
# 29       save    338

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.barplot(data=common_words, x='count', y='word')
plt.title("Top Words in 'Other' Tweets")
plt.show()

# %%
df_clean[df_clean['theme'] == "Other"][
    df_clean['clean_text'].str.contains("delivery|delay|refund|support|tracking", case=False, na=False)
][['tweet_text']].sample(20)
# Out:
# /tmp/ipykernel_7599/3411876860.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_clean[df_clean['theme'] == "Other"][
#                                               tweet_text
# 12617  Are you looking for your new book promotional ...
# 2380   Poor #Amazon They are NOW starting to charge a...
# 7330   Orders pouring in? Get your shipping sorted wi...
# 10898  Dear @amazonIN @amazon If You don't have contr...
# 12630  Are you looking for this kids book promo or ch...
# 10915  @amazonIN Amazon India should be closed, They ...
# 1059   NEW Amazon LEGO Deal - $89.38 (10% OFF)\nCity ...
# 820    Amazon had 3 hr delivery for a wig I wanted JE...
# 4187   @amazon \n@amazonprimenow \nWhy am I paying fo...
# 10358  amazon why would u say i can get same day deli...
# 3864   @AmazonHelp for over 15 months I’ve had issues...
# 12993    Amazon don’t play with that overnight delivery.
# 7756   Dear All @amazonIN @AmazonHelp @jagograhakjago...
# 5714   Dear Amazon Delivery Team,\n\nI wanted to shar...
# 2954   @AmazonHelp My two orders were to be delivered...
# 12599  Are you looking for cinematic book trailer vid...
# 9133   On my way home from working out today, I saw a...
# 3378   you should be able to track your district mana...
# 9460   Amazon expanded drone delivery trials in Europ...
# 3578   🚨 DEAL ALERT 🚨\n\nAmazon eGift Card - Amazon L...

# %%
df_clean['text_length'] = df_clean['clean_text'].apply(lambda x: len(x.split()))

df_clean[df_clean['theme'] == "Other"]['text_length'].describe()
# Out:
# count    11270.000000
# mean        16.775599
# std          7.870781
# min          0.000000
# 25%         10.000000
# 50%         17.000000
# 75%         24.000000
# max         47.000000
# Name: text_length, dtype: float64

# %%
# Remove promotional / irrelevant tweets

promo_keywords = [
    "deal", "sale", "buy", "price", "free", "offer",
    "link", "check", "available", "today", "ad", "promo"
]

def is_promo(text):
    for word in promo_keywords:
        if word in text:
            return True
    return False

df_clean['is_promo'] = df_clean['clean_text'].apply(is_promo)

# %%
# Remove promo tweets

df_filtered = df_clean[df_clean['is_promo'] == False].copy()

print("Before filtering:", df_clean.shape)
print("After filtering:", df_filtered.shape)
# Out:
# Before filtering: (12989, 24)
# After filtering: (5031, 24)

# %%
df_filtered['theme'] = df_filtered['clean_text'].apply(assign_single_theme)

print(df_filtered['theme'].value_counts())
# Out:
# theme
# Other                4202
# Customer Service      344
# Delivery Delay        223
# Fulfillment Issue     163
# Last Mile Issue        73
# Tracking Issue         26
# Name: count, dtype: int64

# %%
df_theme = df_filtered[df_filtered['theme'] != "Other"].copy()

print(df_theme['theme'].value_counts())
# Out:
# theme
# Customer Service     344
# Delivery Delay       223
# Fulfillment Issue    163
# Last Mile Issue       73
# Tracking Issue        26
# Name: count, dtype: int64

# %%
sentiment_theme_table = pd.crosstab(
    df_theme['theme'],
    df_theme['sentiment_label'],
    normalize='index'
) * 100

sentiment_theme_table.round(2)
# Out:
# sentiment_label    Negative  Neutral  Positive
# theme
# Customer Service      19.77    40.41     39.83
# Delivery Delay        22.42    30.49     47.09
# Fulfillment Issue     38.65    31.90     29.45
# Last Mile Issue       31.51    46.58     21.92
# Tracking Issue        30.77    34.62     34.62

# %%
#Prepare modelling dataset

# Features and labels
X = df_theme['clean_text']
y = df_theme['sentiment_label']

print("Dataset size:", X.shape)
print(y.value_counts())
# Out:
# Dataset size: (829,)
# sentiment_label
# Positive    315
# Neutral     302
# Negative    212
# Name: count, dtype: int64

# %%
# Train-test split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Train size:", X_train.shape)
print("Test size:", X_test.shape)
# Out:
# Train size: (663,)
# Test size: (166,)

# %%
# TF-IDF feature engineering

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1,2),   # unigrams + bigrams
    min_df=3,
    max_df=0.9
)

X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

print("TF-IDF train shape:", X_train_tfidf.shape)
print("TF-IDF test shape:", X_test_tfidf.shape)
# Out:
# TF-IDF train shape: (663, 1194)
# TF-IDF test shape: (166, 1194)

# %%
# Model 1 — Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, classification_report

lr_model = LogisticRegression(max_iter=1000, class_weight='balanced')

lr_model.fit(X_train_tfidf, y_train)

lr_preds = lr_model.predict(X_test_tfidf)

print("Logistic Regression Accuracy:", accuracy_score(y_test, lr_preds))
print("Logistic Regression F1 Score:", f1_score(y_test, lr_preds, average='weighted'))

print(classification_report(y_test, lr_preds))
# Out:
# Logistic Regression Accuracy: 0.572289156626506
# Logistic Regression F1 Score: 0.5743932085076549
#               precision    recall  f1-score   support
#
#     Negative       0.49      0.60      0.54        42
#      Neutral       0.54      0.52      0.53        61
#     Positive       0.68      0.60      0.64        63
#
#     accuracy                           0.57       166
#    macro avg       0.57      0.57      0.57       166
# weighted avg       0.58      0.57      0.57       166

# %%
# Confusion matrix

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, lr_preds, labels=lr_model.classes_)

plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=lr_model.classes_,
    yticklabels=lr_model.classes_
)
plt.title("Confusion Matrix - Logistic Regression")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Model 2 — Naive Bayes

from sklearn.naive_bayes import MultinomialNB

nb_model = MultinomialNB()

nb_model.fit(X_train_tfidf, y_train)

nb_preds = nb_model.predict(X_test_tfidf)

print("Naive Bayes Accuracy:", accuracy_score(y_test, nb_preds))
print("Naive Bayes F1 Score:", f1_score(y_test, nb_preds, average='weighted'))

print(classification_report(y_test, nb_preds))
# Out:
# Naive Bayes Accuracy: 0.6024096385542169
# Naive Bayes F1 Score: 0.597564094303995
#               precision    recall  f1-score   support
#
#     Negative       0.71      0.40      0.52        42
#      Neutral       0.53      0.66      0.59        61
#     Positive       0.64      0.68      0.66        63
#
#     accuracy                           0.60       166
#    macro avg       0.63      0.58      0.59       166
# weighted avg       0.62      0.60      0.60       166

# %%
# Compare models

import pandas as pd

results = pd.DataFrame({
    "Model": ["Logistic Regression", "Naive Bayes"],
    "Accuracy": [
        accuracy_score(y_test, lr_preds),
        accuracy_score(y_test, nb_preds)
    ],
    "Weighted F1 Score": [
        f1_score(y_test, lr_preds, average='weighted'),
        f1_score(y_test, nb_preds, average='weighted')
    ]
})

results
# Out:
#                  Model  Accuracy  Weighted F1 Score
# 0  Logistic Regression  0.572289           0.574393
# 1          Naive Bayes  0.602410           0.597564

# %%
# Plot model comparison

results.plot(x="Model", y="Weighted F1 Score", kind="bar", legend=False)
plt.title("Model Performance Comparison")
plt.ylabel("Weighted F1 Score")
plt.ylim(0,1)
plt.xticks(rotation=0)
plt.show()
